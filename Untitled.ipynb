# %%
import csv

with open('greenhouse_gas_data.csv','r') as csvFile:
    csvReader = csv.reader(csvFile, delimiter = ',')
    line_count = 0
    for row in csvReader:
       print(row)
    
##adding some comments here for understanding purpose
# Out:
# ['region', 'anzsic_descriptor', 'gas', 'units', 'magnitude', 'year', 'data_val']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2007', '811.63']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2008', '777.95']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2009', '684']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2010', '706.56']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2011', '764.3']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2012', '725.02']
# ['Auckland', 'Agriculture', 'Carbon dioxide equivalents', 'Kilotonnes', 'Carbon dioxide equivalents', '2013', '707.4']
# ...
